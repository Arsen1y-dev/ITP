# %% [markdown]
# 4.1. Функции. Области видимости. Передача параметров в функции

# %% [markdown]
# Функциональное приветствие

# %%
def print_hello(name):
    print("Hello, " + name + "!")

# %% [markdown]
# Функциональный НОД

# %%
def gcd(a, b):
    while b:
        a, b = b, a % b
    return abs(a)

# %% [markdown]
# 1. Функция gcd принимает два аргумента a и b, которые представляют собой числа, для которых нужно найти НОД.
#
# 2. Внутри функции используется цикл while, который продолжается до тех пор, пока b не станет равным 0. На каждой итерации значения переменных a и b обновляются следующим образом:
#    - Новое значение a присваивается значению b.
#    - Новое значение b присваивается остатку от деления предыдущего значения a на предыдущее значение b.
#
# 3. Когда значение b становится равным 0, цикл завершается, и возвращается абсолютное значение переменной a. Это и есть наибольший общий делитель чисел a и b.
#
# 4. Функция возвращает НОД чисел a и b.
#
# Таким образом, данный код реализует алгоритм Евклида для нахождения наибольшего общего делителя двух чисел a и b.

# %% [markdown]
# Длина числа

# %%
def number_length(n):
    return len(str(abs(n)))

# %% [markdown]
# Имя of the month

# %%
def month(number, language):
    MONTH = {
        'en': [
            'January', 'February', 'March',
            'April', 'May', 'June',
            'July', 'August', 'September',
            'October', 'November', 'December'
        ],
        'ru': [
            'Январь', 'Февраль', 'Март',
            'Апрель', 'Май', 'Июнь',
            'Июль', 'Август', 'Сентябрь',
            'Октябрь', 'Ноябрь', 'Декабрь'
        ]
    }
    return MONTH[language][number - 1]

# %% [markdown]
# 1. Внутри функции определен словарь MONTH, содержащий названия месяцев на двух языках: английском и русском. Ключами в словаре являются языковые коды 'en' и 'ru', а значениями — списки названий месяцев на соответствующем языке.
#
# 2. Функция использует переданный языковой код language для выбора соответствующего списка названий месяцев из словаря MONTH.
#
# 3. После выбора списка названий месяцев на нужном языке, функция обращается к элементу списка с индексом (number - 1) (так как индексация в Python начинается с 0, а номерация месяцев обычно начинается с 1).
#
# 4. Функция возвращает название месяца, соответствующее переданному номеру и языку.
#
# Например, если вызвать функцию month(1, 'ru'), она вернет 'Январь', так как при number=1 и language='ru' функция обратится к первому элементу списка русских названий месяцев, который соответствует январю.

# %% [markdown]
# Числовая строка

# %%
def split_numbers(n):
    n = n.split()
    return tuple(map(int, n))
print(split_numbers("1 2 3 4 5"))
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# 1. Функция split_numbers принимает строку n, содержащую числа, разделенные пробелами.
#
# 2. Сначала строка n разбивается на список подстрок с помощью метода split(), используя пробел как разделитель. Это преобразует строку в список строк, каждая из которых представляет отдельное число.
#
# 3. Затем функция применяет функцию int с помощью map, чтобы преобразовать каждую строку в списке в целое число. Функция map(int, n) выполняет преобразование каждого элемента списка n в целое число.
#
# 4. Результат работы функции map(int, n) оборачивается в вызов tuple(), чтобы преобразовать список целых чисел в кортеж.
#
# 5. Наконец, функция возвращает кортеж, содержащий целые числа, извлеченные из строки входных данных.
#
# Например, если вызвать функцию split_numbers("1 2 3 4 5"), она вернет кортеж (1, 2, 3, 4, 5), так как строка "1 2 3 4 5" будет разбита на отдельные числа и преобразована в кортеж целых чисел.

# %% [markdown]
# Модернизация системы вывода

# %%
a=[]
def modern_print(n):
    if n not in a:
        a.append(n)
        print(n)
          
# тест       
modern_print("Hello!")
modern_print("Hello!")
modern_print("How do you do?")
modern_print("Hello!")
# Out:
# Hello!
# How do you do?

# %% [markdown]
# Шахматный «обед»

# %%
def can_eat(horse, shape):
    return abs(horse[0] - shape[0]) + abs(horse[1] - shape[1]) == 3

# %% [markdown]
# 1. Функция can_eat вычисляет сумму модулей разностей координат x и y между лошадью и фигурой: abs(horse[0] - shape[0]) + abs(horse[1] - shape[1]).
#
# 2. Если эта сумма равна 3, то лошадь может съесть фигуру за один ход, так как лошадь ходит по правилам шахматной игры L-образно, двигаясь на 2 клетки по одной оси и на 1 клетку по другой оси.
#
# 3. Возвращается булево значение: True, если лошадь может съесть фигуру за один ход, и False, если нет.
#
# Например, если вызвать функцию can_eat((1, 2), (3, 3)), то результат будет True, так как разница по x равна 2, а по y равна 1, что в сумме даёт 3, что соответствует возможности лошади съесть фигуру за один ход.

# %% [markdown]
# А роза упала на лапу Азора 7.0

# %%
def is_palindrome(n):
    return str(n) == str(n)[::-1] if isinstance(n, int) else n == n[::-1]

# %% [markdown]
# 1. Сначала код проверяет, является ли n целым числом (int) с помощью условия isinstance(n, int). Если n не является целым числом, то функция сравнивает n с самим собой в обратном порядке (для строк).
#
# 2. Если n является целым числом, то оно преобразуется в строку с помощью str(n). Затем проверяется, равна ли эта строка своему обратному порядку, полученному с помощью среза [::-1]. Если строка равна своему обратному порядку, то число n является палиндромом.
#
# 3. Если n не является целым числом, то предполагается, что n уже является строкой, и происходит сравнение строки с её обратным порядком.
#
# 4. Возвращается булево значение: True, если n является палиндромом, и False, если нет.
#
# Например, если вызвать функцию is_palindrome(12321), результат будет True, так как число 12321 читается одинаково как слева направо, так и справа налево.

# %% [markdown]
# Простая задача 5.0

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# 1. Сначала код проверяет, является ли число n меньше 2. Если n меньше 2, то функция сразу возвращает False, потому что простые числа по определению больше или равны 2.
#
# 2. Затем происходит цикл for, который итерируется от 2 до квадратного корня из n плюс 1 (int(n**0.5) + 1). Это делается для оптимизации, так как если число делится на какое-либо число больше его квадратного корня, то оно также делится и на число меньше квадратного корня.
#
# 3. Внутри цикла проверяется, делится ли число n на текущее значение i без остатка (т.е. n % i == 0). Если делится без остатка, то число n не является простым, и функция возвращает False.
#
# 4. Если ни одно из чисел в диапазоне от 2 до квадратного корня из n не является делителем числа n, то функция возвращает True, указывая на то, что число n является простым.
#
# Например, если вызвать функцию is_prime(17), результат будет True, так как число 17 является простым числом.

# %% [markdown]
# Слияние

# %% [markdown]
# ПОЧИНИТЬ!

# %%
def merge(t1, *t):
    result = []
    i, j = 0, 0
    
    while i < len(t1) and j:
        if t1[i] <= t[j][0]:
            result.append(t1[i])
            i += 1
        else:
            result.append(t[j][0])
            j += 1
            
    result.extend(t[j:])
    return tuple(result)

# %%
import antigravity
